# %%
import pandas as pd
import folium

# %%
df = pd.read_csv("countries.csv")
df.head(10)
# Out:
#    id                 name iso3 iso2  numeric_code phone_code  \
# 0   1          Afghanistan  AFG   AF             4         93
# 1   2        Aland Islands  ALA   AX           248    +358-18
# 2   3              Albania  ALB   AL             8        355
# 3   4              Algeria  DZA   DZ            12        213
# 4   5       American Samoa  ASM   AS            16     +1-684
# 5   6              Andorra  AND   AD            20        376
# 6   7               Angola  AGO   AO            24        244
# 7   8             Anguilla  AIA   AI           660     +1-264
# 8   9           Antarctica  ATA   AQ            10        672
# 9  10  Antigua And Barbuda  ATG   AG            28     +1-268
#
#             capital currency             currency_name currency_symbol  tld  \
# 0             Kabul      AFN            Afghan afghani               ؋  .af
# 1         Mariehamn      EUR                      Euro               €  .ax
# 2            Tirana      ALL              Albanian lek             Lek  .al
# 3           Algiers      DZD            Algerian dinar              دج  .dz
# 4         Pago Pago      USD                 US Dollar               $  .as
# 5  Andorra la Vella      EUR                      Euro               €  .ad
# 6            Luanda      AOA            Angolan kwanza              Kz  .ao
# 7        The Valley      XCD     East Caribbean dollar               $  .ai
# 8               NaN      AAD        Antarctican dollar               $  .aq
# 9        St. John's      XCD  Eastern Caribbean dollar               $  .ag
#
#                 native    region        subregion  \
# 0            افغانستان      Asia    Southern Asia
# 1                Åland    Europe  Northern Europe
# 2            Shqipëria    Europe  Southern Europe
# 3              الجزائر    Africa  Northern Africa
# 4       American Samoa   Oceania        Polynesia
# 5              Andorra    Europe  Southern Europe
# 6               Angola    Africa    Middle Africa
# 7             Anguilla  Americas        Caribbean
# 8           Antarctica     Polar              NaN
# 9  Antigua and Barbuda  Americas        Caribbean
#
#                                            timezones   latitude   longitude  \
# 0  [{zoneName:'Asia\/Kabul',gmtOffset:16200,gmtOf...  33.000000   65.000000
# 1  [{zoneName:'Europe\/Mariehamn',gmtOffset:7200,...  60.116667   19.900000
# 2  [{zoneName:'Europe\/Tirane',gmtOffset:3600,gmt...  41.000000   20.000000
# 3  [{zoneName:'Africa\/Algiers',gmtOffset:3600,gm...  28.000000    3.000000
# 4  [{zoneName:'Pacific\/Pago_Pago',gmtOffset:-396... -14.333333 -170.000000
# 5  [{zoneName:'Europe\/Andorra',gmtOffset:3600,gm...  42.500000    1.500000
# 6  [{zoneName:'Africa\/Luanda',gmtOffset:3600,gmt... -12.500000   18.500000
# 7  [{zoneName:'America\/Anguilla',gmtOffset:-1440...  18.250000  -63.166667
# 8  [{zoneName:'Antarctica\/Casey',gmtOffset:39600... -74.650000    4.480000
# 9  [{zoneName:'America\/Antigua',gmtOffset:-14400...  17.050000  -61.800000
#
#   emoji           emojiU
# 0    🇦🇫  U+1F1E6 U+1F1EB
# 1    🇦🇽  U+1F1E6 U+1F1FD
# 2    🇦🇱  U+1F1E6 U+1F1F1
# 3    🇩🇿  U+1F1E9 U+1F1FF
# 4    🇦🇸  U+1F1E6 U+1F1F8
# 5    🇦🇩  U+1F1E6 U+1F1E9
# 6    🇦🇴  U+1F1E6 U+1F1F4
# 7    🇦🇮  U+1F1E6 U+1F1EE
# 8    🇦🇶  U+1F1E6 U+1F1F6
# 9    🇦🇬  U+1F1E6 U+1F1EC

# %%
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

# %%
m = folium.Map(location=[center_lat, center_lon], zoom_start=5)

# %%
for idx, row in df.iterrows():
  folium.Marker(
      location=[row['latitude'], row['longitude']],
      popup=row['name'],
      tooltip=row['name']
  ).add_to(m)

# %%
m.save('countries_map.html')
